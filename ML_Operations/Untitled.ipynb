# %%
import pandas as pd

# %%
df = pd.read_csv('flat_data.csv')

# %%
df.head()
# Out:
#      PROP_ID PROPERTY_TYPE           SOCIETY_NAME           CITY     location  \
# 0  J71214794          flat        Bhawani bandhan  Kolkata North  Madhyamgram
# 1  F70835394          flat  Ganguly 4sight desire  Kolkata South        Garia
# 2  P69854924          flat       Dtc capital city   Kolkata East     Rajarhat
# 3  E69854912          flat       Dtc capital city   Kolkata East     Rajarhat
# 4  R69167152          flat           Sai sarovaar   Kolkata East     New Town
#
#    BEDROOM_NUM  BALCONY_NUM  AREA  Price_per_sqft  PRICE           AGE  \
# 0          2.0          1.0   920          4239.0   0.39  Old Property
# 1          1.0          1.0   535          5100.0   0.27  Old Property
# 2          4.0          2.0  1940          4742.0   0.92  Old Property
# 3          2.0          1.0   910          4615.0   0.42  Old Property
# 4          3.0          1.0  1163          4700.0   0.55  Old Property
#
# ...

# %%
image = [
    'https://cdn.pixabay.com/photo/2017/04/10/22/28/residence-2219972_640.jpg',
    'https://cdn.pixabay.com/photo/2016/11/18/17/46/house-1836070_1280.jpg',
    'https://cdn.pixabay.com/photo/2014/07/10/17/18/large-home-389271_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/06/13/22/42/kitchen-2400367_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/07/08/02/16/house-2483336_1280.jpg',
    'https://cdn.pixabay.com/photo/2015/09/27/22/36/house-961401_1280.jpg',
    'https://cdn.pixabay.com/photo/2014/08/03/23/41/house-409451_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/06/19/04/06/house-2418106_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/07/08/06/48/sa-rapita-2483668_960_720.jpg',
    'https://cdn.pixabay.com/photo/2016/11/29/03/53/house-1867187_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/06/13/22/42/twilight-2400368_1280.jpg',
    'https://cdn.pixabay.com/photo/2018/02/13/11/09/home-3150500_1280.jpg',
    'https://cdn.pixabay.com/photo/2014/10/05/22/40/family-home-475879_1280.jpg',
    'https://cdn.pixabay.com/photo/2017/06/16/13/40/new-home-2409165_960_720.jpg',
    'https://cdn.pixabay.com/photo/2017/07/17/00/54/house-2511060_1280.jpg',
    'https://cdn.pixabay.com/photo/2021/11/16/02/23/house-6799908_1280.jpg',
    'https://cdn.pixabay.com/photo/2018/04/04/21/21/lawn-3291164_1280.jpg',
    'https://cdn.pixabay.com/photo/2019/10/26/11/40/building-4579244_1280.jpg',
    'https://cdn.pixabay.com/photo/2020/03/21/20/03/real-estate-4955087_1280.jpg',
]

# %%
len(image)
# Out:
# 19

# %%
image = list(set(image))

# %%
len(image)
# Out:
# 19

# %%
image
# Out:
# ['https://cdn.pixabay.com/photo/2015/09/27/22/36/house-961401_1280.jpg',
#  'https://cdn.pixabay.com/photo/2014/10/05/22/40/family-home-475879_1280.jpg',
#  'https://cdn.pixabay.com/photo/2020/03/21/20/03/real-estate-4955087_1280.jpg',
#  'https://cdn.pixabay.com/photo/2017/06/19/04/06/house-2418106_1280.jpg',
#  'https://cdn.pixabay.com/photo/2017/06/16/13/40/new-home-2409165_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2018/04/04/21/21/lawn-3291164_1280.jpg',
#  'https://cdn.pixabay.com/photo/2017/07/08/02/16/house-2483336_1280.jpg',
#  'https://cdn.pixabay.com/photo/2017/06/13/22/42/kitchen-2400367_1280.jpg',
#  'https://cdn.pixabay.com/photo/2016/11/29/03/53/house-1867187_1280.jpg',
#  'https://cdn.pixabay.com/photo/2017/07/08/06/48/sa-rapita-2483668_960_720.jpg',
#  'https://cdn.pixabay.com/photo/2014/07/10/17/18/large-home-389271_1280.jpg',
#  'https://cdn.pixabay.com/photo/2019/10/26/11/40/building-4579244_1280.jpg',
# ...

# %%
df['Image'] = 0

# %%
df
# Out:
#         PROP_ID PROPERTY_TYPE                  SOCIETY_NAME           CITY  \
# 0     J71214794          flat               Bhawani bandhan  Kolkata North
# 1     F70835394          flat         Ganguly 4sight desire  Kolkata South
# 2     P69854924          flat              Dtc capital city   Kolkata East
# 3     E69854912          flat              Dtc capital city   Kolkata East
# 4     R69167152          flat                  Sai sarovaar   Kolkata East
# ...         ...           ...                           ...            ...
# 5143  U71217472          flat              Shyama apartment  Kolkata South
# 5144  E64737128          flat                        Privet  Kolkata South
# 5145  J66826540          flat  Ambuja upohar the condoville  Kolkata South
# 5146  E66826562          flat  Ambuja upohar the condoville  Kolkata South
# 5147  J71210104          flat          Dlf new town heights   Kolkata East
#
# ...

# %%
import random


for index in df.index:
    no = random.randint(0, 18)  
    df.at[index, 'Image'] = image[no]
# Out:
# C:\Users\dipan\AppData\Local\Temp\ipykernel_14912\887508904.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'https://cdn.pixabay.com/photo/2017/06/16/13/40/new-home-2409165_960_720.jpg' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'Image'] = image[no]

# %%
df['Image']
# Out:
# 0       https://cdn.pixabay.com/photo/2017/06/16/13/40...
# 1       https://cdn.pixabay.com/photo/2015/09/27/22/36...
# 2       https://cdn.pixabay.com/photo/2017/07/17/00/54...
# 3       https://cdn.pixabay.com/photo/2018/04/04/21/21...
# 4       https://cdn.pixabay.com/photo/2018/02/13/11/09...
#                               ...
# 5143    https://cdn.pixabay.com/photo/2021/11/16/02/23...
# 5144    https://cdn.pixabay.com/photo/2016/11/29/03/53...
# 5145    https://cdn.pixabay.com/photo/2018/02/13/11/09...
# 5146    https://cdn.pixabay.com/photo/2018/04/04/21/21...
# 5147    https://cdn.pixabay.com/photo/2017/07/17/00/54...
# Name: Image, Length: 5148, dtype: object

# %%
df
# Out:
#         PROP_ID PROPERTY_TYPE                  SOCIETY_NAME           CITY  \
# 0     J71214794          flat               Bhawani bandhan  Kolkata North
# 1     F70835394          flat         Ganguly 4sight desire  Kolkata South
# 2     P69854924          flat              Dtc capital city   Kolkata East
# 3     E69854912          flat              Dtc capital city   Kolkata East
# 4     R69167152          flat                  Sai sarovaar   Kolkata East
# ...         ...           ...                           ...            ...
# 5143  U71217472          flat              Shyama apartment  Kolkata South
# 5144  E64737128          flat                        Privet  Kolkata South
# 5145  J66826540          flat  Ambuja upohar the condoville  Kolkata South
# 5146  E66826562          flat  Ambuja upohar the condoville  Kolkata South
# 5147  J71210104          flat          Dlf new town heights   Kolkata East
#
# ...

# %%
df['Situation'] = 0

# %%
situation_list = ['Ready To Move', 'Under Constraction']

# %%
import random


for index in df.index:
    no = random.randint(0, 1)  
    df.at[index, 'Situation'] = situation_list[no]
# Out:
# C:\Users\dipan\AppData\Local\Temp\ipykernel_14912\3752816898.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Ready To Move' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'Situation'] = situation_list[no]

# %%
df
# Out:
#         PROP_ID PROPERTY_TYPE                  SOCIETY_NAME           CITY  \
# 0     J71214794          flat               Bhawani bandhan  Kolkata North
# 1     F70835394          flat         Ganguly 4sight desire  Kolkata South
# 2     P69854924          flat              Dtc capital city   Kolkata East
# 3     E69854912          flat              Dtc capital city   Kolkata East
# 4     R69167152          flat                  Sai sarovaar   Kolkata East
# ...         ...           ...                           ...            ...
# 5143  U71217472          flat              Shyama apartment  Kolkata South
# 5144  E64737128          flat                        Privet  Kolkata South
# 5145  J66826540          flat  Ambuja upohar the condoville  Kolkata South
# 5146  E66826562          flat  Ambuja upohar the condoville  Kolkata South
# 5147  J71210104          flat          Dlf new town heights   Kolkata East
#
# ...

# %%
df['Owner_Type'] = 0

# %%
owner_list = ['Owner', 'Broker']

# %%
import random


for index in df.index:
    no = random.randint(0, 1)  
    df.at[index, 'Owner_Type'] = owner_list[no]
# Out:
# C:\Users\dipan\AppData\Local\Temp\ipykernel_14912\3051960085.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Owner' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'Owner_Type'] = owner_list[no]

# %%
df['Contact'] = 0

# %%
# Adding contact numbers as strings
for index in df.index:
    no = random.randint(1000000000, 9999999999)
    df.at[index, 'Contact'] = f"+91-{no}"
# Out:
# C:\Users\dipan\AppData\Local\Temp\ipykernel_14912\2506556531.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '+91-1690606093' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[index, 'Contact'] = f"+91-{no}"

# %%
df
# Out:
#         PROP_ID PROPERTY_TYPE                  SOCIETY_NAME           CITY  \
# 0     J71214794          flat               Bhawani bandhan  Kolkata North
# 1     F70835394          flat         Ganguly 4sight desire  Kolkata South
# 2     P69854924          flat              Dtc capital city   Kolkata East
# 3     E69854912          flat              Dtc capital city   Kolkata East
# 4     R69167152          flat                  Sai sarovaar   Kolkata East
# ...         ...           ...                           ...            ...
# 5143  U71217472          flat              Shyama apartment  Kolkata South
# 5144  E64737128          flat                        Privet  Kolkata South
# 5145  J66826540          flat  Ambuja upohar the condoville  Kolkata South
# 5146  E66826562          flat  Ambuja upohar the condoville  Kolkata South
# 5147  J71210104          flat          Dlf new town heights   Kolkata East
#
# ...

# %%
df.to_csv('flatData.csv', index=False)
